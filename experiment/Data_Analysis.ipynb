# %% [markdown]
# #### Load the data.
# #### Check the missing values.
# #### Correlation analysis.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mode_choice_data.csv")
print(df.shape)
# Out:
# (305, 105)

# %%
df.head()
# Out:
#    id  Travel_Time  travel_cost  \tcomfort  reliability  safety  \
# 0   1            6            7          5            6       7
# 1   3            7            6          7            7       6
# 2  11            7            7          4            6       7
# 3  12            6            6          6            6       4
# 4  14            5            6          5            5       6
#
#    accessibility  service_frequency  \twait_time  in_vehicle_time  ...  age  \
# 0              6                  6            6                6  ...   32
# 1              7                  7            7                7  ...   25
# 2              5                  6            6                6  ...   21
# 3              6                  6            6                6  ...   22
# 4              4                  7            4                5  ...   38
#
#    gender  marital  people  yrsjob  cusinter  yrsfirm  educ  income  \
# 0       2      3.0       1       2      80.0      3.0     2     2.0
# 1       2      2.0       1       0      55.0      3.0     2     2.0
# 2       2      1.0       3       1     180.0      1.0     2     2.0
# 3       2      4.0       6       0     200.0      3.0     2     2.0
# 4       2      1.0       5       2     999.0      2.0     1     2.0
#
#    travel_mode
# 0            3
# 1            2
# 2            3
# 3            3
# 4            3
#
# [5 rows x 105 columns]

# %%
df.columns
# Out:
# Index(['id', 'Travel_Time', 'travel_cost', '\tcomfort', 'reliability',
#        'safety', 'accessibility', 'service_frequency', '\twait_time',
#        'in_vehicle_time',
#        ...
#        'age', 'gender', 'marital', 'people', 'yrsjob', 'cusinter', 'yrsfirm',
#        'educ', 'income', 'travel_mode'],
#       dtype='object', length=105)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Columns: 105 entries, id to travel_mode
# dtypes: float64(5), int64(100)
# memory usage: 250.3 KB

# %%
for i in list(df.columns):
    print(f"Column {i}")
    print(df[i].value_counts())
# Out:
# Column id
# id
# 341    3
# 478    2
# 87     2
# 82     2
# 68     2
#       ..
# 377    1
# 378    1
# 380    1
# 473    1
# 479    1
# Name: count, Length: 258, dtype: int64
# Column Travel_Time
# Travel_Time
# 6    118
# 7     67
# 5     63
# 4     38
# 3     17
# 2      2
# Name: count, dtype: int64
# Column travel_cost
# travel_cost
# 6    135
# 7     97
# 5     40
# 4     19
# 3     14
# Name: count, dtype: int64
# Column 	comfort
# \tcomfort
# 6    72
# 5    63
# 7    51
# 4    51
# 3    48
# 2    14
# 1     6
# Name: count, dtype: int64
# Column reliability
# reliability
# 6    116
# 7     86
# 5     54
# 4     26
# 3     19
# 2      3
# 1      1
# Name: count, dtype: int64
# Column safety
# safety
# 6    125
# 7     96
# 5     46
# 4     24
# 3     14
# Name: count, dtype: int64
# Column accessibility
# accessibility
# 6    104
# 7     80
# 5     67
# 4     29
# 3     17
# 2      4
# 1      4
# Name: count, dtype: int64
# Column service_frequency
# service_frequency
# 6    105
# 7     76
# 5     61
# 4     37
# 3     21
# 2      3
# 1      2
# Name: count, dtype: int64
# Column 	wait_time
# \twait_time
# 6    119
# 7     80
# 5     51
# 4     35
# 3     19
# 1      1
# Name: count, dtype: int64
# Column in_vehicle_time
# in_vehicle_time
# 6    107
# 7     81
# 5     63
# 4     36
# 3     15
# 1      2
# 2      1
# Name: count, dtype: int64
# Column crowding
# crowding
# 6    108
# 5     73
# 7     71
# 4     32
# 3     14
# 2      6
# 1      1
# Name: count, dtype: int64
# Column seat_availability
# seat_availability
# 6    115
# 7    102
# 5     52
# 4     22
# 3     12
# 2      2
# Name: count, dtype: int64
# Column route_directness
# route_directness
# 6    124
# 7     90
# 5     53
# 4     18
# 3     17
# 1      3
# Name: count, dtype: int64
# Column transfer_ease
# transfer_ease
# 6    134
# 7     84
# 5     53
# 4     25
# 3      8
# 2      1
# Name: count, dtype: int64
# Column parking_availability
# parking_availability
# 6    116
# 7     68
# 5     66
# 4     35
# 3     19
# 1      1
# Name: count, dtype: int64
# Column fare_integration
# fare_integration
# 6    119
# 7     88
# 5     55
# 4     31
# 3     12
# Name: count, dtype: int64
# Column ticketing_ease
# ticketing_ease
# 6    126
# 7     78
# 5     65
# 4     26
# 3     10
# Name: count, dtype: int64
# Column service_image
# service_image
# 6    123
# 7     83
# 5     54
# 4     35
# 3     10
# Name: count, dtype: int64
# Column habitual_mode_choice
# habitual_mode_choice
# 6    81
# 5    75
# 7    70
# 4    41
# 3    26
# 2     7
# 1     5
# Name: count, dtype: int64
# Column perceived_safety
# perceived_safety
# 6    83
# 7    81
# 5    70
# 4    32
# 3    26
# 2    11
# 1     2
# Name: count, dtype: int64
# Column social_influence
# social_influence
# 6    102
# 5     68
# 7     67
# 4     36
# 3     26
# 2      4
# 1      2
# Name: count, dtype: int64
# Column trip_purpose
# trip_purpose
# 7    103
# 6     89
# 5     60
# 4     26
# 3     19
# 2      6
# 1      2
# Name: count, dtype: int64
# Column daily_trip_count
# daily_trip_count
# 6    110
# 7    101
# 5     55
# 4     23
# 3     14
# 2      2
# Name: count, dtype: int64
# Column time_of_travel
# time_of_travel
# 6    106
# 7     93
# 5     64
# 4     24
# 3     14
# 2      3
# 1      1
# Name: count, dtype: int64
# Column willingness_to_shift
# willingness_to_shift
# 6    102
# 5     78
# 7     72
# 4     32
# 3     15
# 2      5
# 1      1
# Name: count, dtype: int64
# Column sidewalk_quality
# sidewalk_quality
# 4    132
# 3     72
# 2     52
# 5     29
# 1     20
# Name: count, dtype: int64
# Column pedestrian_safety
# pedestrian_safety
# 4    118
# 3     92
# 2     59
# 5     19
# 1     17
# Name: count, dtype: int64
# Column crossing_facility
# crossing_facility
# 4    146
# 2     63
# 3     48
# 5     28
# 1     20
# Name: count, dtype: int64
# Column transit_connectivity
# transit_connectivity
# 4    115
# 3    105
# 2     48
# 5     25
# 1     12
# Name: count, dtype: int64
# Column 	interchange_ease
# \tinterchange_ease
# 3    100
# 4     99
# 2     71
# 1     23
# 5     12
# Name: count, dtype: int64
# Column last_mile_option
# last_mile_option
# 3    99
# 4    95
# 2    58
# 1    29
# 5    24
# Name: count, dtype: int64
# Column bike_parking
# bike_parking
# 2    118
# 1     85
# 3     43
# 4     40
# 5     14
# 6      5
# Name: count, dtype: int64
# Column bike_lane_availability
# bike_lane_availability
# 2    130
# 1     61
# 3     53
# 4     42
# 5     12
# 6      7
# Name: count, dtype: int64
# Column shared_bicycle_use
# shared_bicycle_use
# 2    167
# 1     93
# 3     37
# 4      5
# 5      2
# 6      1
# Name: count, dtype: int64
# Column bike_safety
# bike_safety
# 2    166
# 1     88
# 3     40
# 4      8
# 5      2
# 6      1
# Name: count, dtype: int64
# Column cycling_slope
# cycling_slope
# 2    92
# 1    76
# 3    52
# 4    50
# 5    27
# 6     8
# Name: count, dtype: int64
# Column 	bike_rack_access
# \tbike_rack_access
# 2    77
# 3    75
# 4    72
# 1    44
# 5    29
# 6     8
# Name: count, dtype: int64
# Column station_spacing
# station_spacing
# 2    73
# 4    69
# 3    51
# 5    41
# 6    40
# 1    31
# Name: count, dtype: int64
# Column 	station_quality
# \tstation_quality
# 2    80
# 5    56
# 4    53
# 3    44
# 6    38
# 1    34
# Name: count, dtype: int64
# Column 	feeder_service
# \tfeeder_service
# 2    152
# 3     74
# 1     34
# 4     22
# 5     14
# 6      9
# Name: count, dtype: int64
# Column 	real_time_info
# \treal_time_info
# 2    147
# 3     81
# 1     36
# 4     18
# 5     14
# 6      9
# Name: count, dtype: int64
# Column 	shelter_availability
# \tshelter_availability
# 2    71
# 1    56
# 5    53
# 4    52
# 3    39
# 6    34
# Name: count, dtype: int64
# Column disabled_access
# disabled_access
# 5    67
# 2    61
# 4    54
# 6    50
# 3    37
# 1    36
# Name: count, dtype: int64
# Column land_use_mix
# land_use_mix
# 4    133
# 3     93
# 5     44
# 2     28
# 1      7
# Name: count, dtype: int64
# Column development_density
# development_density
# 4    140
# 3     94
# 5     37
# 2     27
# 1      7
# Name: count, dtype: int64
# Column building_footprint
# building_footprint
# 4    143
# 3     94
# 5     46
# 2     17
# 1      5
# Name: count, dtype: int64
# Column road_condition
# road_condition
# 3.0    122
# 2.0     78
# 4.0     68
# 1.0     21
# 5.0     15
# Name: count, dtype: int64
# Column traffic_flow
# traffic_flow
# 3    103
# 4     80
# 5     54
# 2     49
# 1     19
# Name: count, dtype: int64
# Column 	signalized_intersection
# \tsignalized_intersection
# 2    113
# 3    108
# 4     38
# 1     27
# 5     19
# Name: count, dtype: int64
# Column road_safety
# road_safety
# 3    94
# 4    80
# 2    69
# 5    42
# 1    20
# Name: count, dtype: int64
# Column 	road_accessibility
# \troad_accessibility
# 2    116
# 3     94
# 1     50
# 4     38
# 5      7
# Name: count, dtype: int64
# Column entry_points
# entry_points
# 2    109
# 3     97
# 4     48
# 1     29
# 5     22
# Name: count, dtype: int64
# Column network_connectivity
# network_connectivity
# 3    95
# 4    86
# 5    84
# 2    32
# 1     8
# Name: count, dtype: int64
# Column grid_structure
# grid_structure
# 3    88
# 4    80
# 2    71
# 5    47
# 1    19
# Name: count, dtype: int64
# Column cul_de_sacs
# cul_de_sacs
# 3    94
# 2    80
# 4    64
# 5    49
# 1    18
# Name: count, dtype: int64
# Column walkability_score
# walkability_score
# 5    74
# 3    71
# 2    63
# 4    55
# 1    42
# Name: count, dtype: int64
# Column 	pedestrian_priority
# \tpedestrian_priority
# 3    73
# 2    71
# 5    62
# 4    52
# 1    47
# Name: count, dtype: int64
# Column congestion_level
# congestion_level
# 3    116
# 4     96
# 5     62
# 2     29
# 1      2
# Name: count, dtype: int64
# Column 	perceived_delay
# \tperceived_delay
# 3    127
# 4     80
# 5     56
# 2     37
# 1      5
# Name: count, dtype: int64
# Column avoidance_behavior
# avoidance_behavior
# 3    120
# 2     71
# 4     70
# 5     40
# 1      4
# Name: count, dtype: int64
# Column time_buffer
# time_buffer
# 3    122
# 4     70
# 2     63
# 5     34
# 1     16
# Name: count, dtype: int64
# Column air_quality
# air_quality
# 2    105
# 1     72
# 3     57
# 4     41
# 5     30
# Name: count, dtype: int64
# Column noise_level
# noise_level
# 2    128
# 3     84
# 1     50
# 4     25
# 5     18
# Name: count, dtype: int64
# Column 	green_coverage
# \tgreen_coverage
# 3    90
# 2    73
# 1    63
# 4    49
# 5    30
# Name: count, dtype: int64
# Column heat_index
# heat_index
# 2    118
# 3     74
# 1     51
# 4     42
# 5     20
# Name: count, dtype: int64
# Column sustainability_awareness
# sustainability_awareness
# 1    111
# 2     88
# 3     59
# 4     27
# 5     20
# Name: count, dtype: int64
# Column mixed_use_zoning
# mixed_use_zoning
# 3    127
# 4     71
# 2     63
# 5     29
# 1     15
# Name: count, dtype: int64
# Column vertical_mixing
# vertical_mixing
# 3    95
# 2    75
# 4    70
# 5    42
# 1    23
# Name: count, dtype: int64
# Column 	land_cost
# \tland_cost
# 2    119
# 3     83
# 4     57
# 1     24
# 5     22
# Name: count, dtype: int64
# Column 	land_value
# \tland_value
# 2    92
# 3    92
# 4    73
# 5    27
# 1    21
# Name: count, dtype: int64
# Column 	real_estate_trend
# \treal_estate_trend
# 2    100
# 3     90
# 4     60
# 1     33
# 5     22
# Name: count, dtype: int64
# Column 	zoning_regulation
# \tzoning_regulation
# 2    131
# 3     80
# 4     39
# 1     39
# 5     16
# Name: count, dtype: int64
# Column population_density
# population_density
# 5    89
# 4    71
# 3    67
# 1    40
# 2    38
# Name: count, dtype: int64
# Column job_density
# job_density
# 5    98
# 4    79
# 3    56
# 2    41
# 1    31
# Name: count, dtype: int64
# Column urban_connectivity
# urban_connectivity
# 2    137
# 3     76
# 1     64
# 4     22
# 5      6
# Name: count, dtype: int64
# Column transit_catchment
# transit_catchment
# 2    147
# 1     72
# 3     72
# 4     10
# 5      4
# Name: count, dtype: int64
# Column block_size
# block_size
# 2    105
# 3     89
# 4     50
# 1     38
# 5     23
# Name: count, dtype: int64
# Column design_quality
# design_quality
# 2    94
# 1    81
# 3    72
# 4    39
# 5    19
# Name: count, dtype: int64
# Column aesthetics
# aesthetics
# 2    80
# 3    75
# 1    63
# 5    44
# 4    43
# Name: count, dtype: int64
# Column street_furniture
# street_furniture
# 2    98
# 1    95
# 3    58
# 4    34
# 5    20
# Name: count, dtype: int64
# Column street_lighting
# street_lighting
# 1    119
# 2     94
# 3     56
# 5     20
# 4     16
# Name: count, dtype: int64
# Column metro_proximity
# metro_proximity
# 4    123
# 3     76
# 2     49
# 5     36
# 1     21
# Name: count, dtype: int64
# Column bus_stop_access
# bus_stop_access
# 4    142
# 3     81
# 2     40
# 5     29
# 1     13
# Name: count, dtype: int64
# Column transit_access_index
# transit_access_index
# 4    110
# 3     99
# 2     52
# 5     27
# 1     17
# Name: count, dtype: int64
# Column travel_frequency
# travel_frequency
# 4    130
# 2     64
# 3     62
# 5     34
# 1     15
# Name: count, dtype: int64
# Column commute_duration
# commute_duration
# 4    123
# 2     76
# 3     54
# 5     34
# 1     18
# Name: count, dtype: int64
# Column peak_hour_travel
# peak_hour_travel
# 4    128
# 3     64
# 2     62
# 5     41
# 1     10
# Name: count, dtype: int64
# Column multimodal_usage
# multimodal_usage
# 4    144
# 3     60
# 5     51
# 2     43
# 1      7
# Name: count, dtype: int64
# Column parking_fee
# parking_fee
# 1    239
# 2     39
# 3     12
# 4     10
# 5      5
# Name: count, dtype: int64
# Column park_ride_availability
# park_ride_availability
# 1    142
# 2     79
# 3     44
# 4     35
# 5      5
# Name: count, dtype: int64
# Column permit_parking
# permit_parking
# 1    211
# 2     60
# 3     18
# 4     12
# 5      4
# Name: count, dtype: int64
# Column car_free_zone
# car_free_zone
# 1    140
# 2     69
# 3     57
# 4     34
# 5      5
# Name: count, dtype: int64
# Column work_accessibility
# work_accessibility
# 4    100
# 2     79
# 3     76
# 5     25
# 1     25
# Name: count, dtype: int64
# Column shopping_accessibility
# shopping_accessibility
# 4    112
# 3     79
# 2     70
# 5     26
# 1     18
# Name: count, dtype: int64
# Column healthcare_access
# healthcare_access
# 2    99
# 4    88
# 3    73
# 1    30
# 5    15
# Name: count, dtype: int64
# Column age
# age
# 25    32
# 24    30
# 23    24
# 30    18
# 21    17
# 26    13
# 29    13
# 22    12
# 32    11
# 28    11
# 33    10
# 37     8
# 40     8
# 20     7
# 27     7
# 31     6
# 50     6
# 39     5
# 43     5
# 42     4
# 18     4
# 48     4
# 36     4
# 49     4
# 35     4
# 19     4
# 45     3
# 38     3
# 41     3
# 47     3
# 34     3
# 54     3
# 52     2
# 51     2
# 56     2
# 44     2
# 60     1
# 58     1
# 59     1
# 61     1
# 63     1
# 73     1
# 46     1
# 57     1
# Name: count, dtype: int64
# Column gender
# gender
# 2    226
# 1     79
# Name: count, dtype: int64
# Column marital
# marital
# 1.0    189
# 4.0     45
# 3.0     29
# 2.0     29
# 5.0     11
# Name: count, dtype: int64
# Column people
# people
# 2     87
# 3     68
# 4     56
# 5     30
# 1     28
# 6     20
# 7      9
# 8      3
# 9      2
# 10     2
# Name: count, dtype: int64
# Column yrsjob
# yrsjob
# 2     92
# 3     77
# 1     72
# 0     60
# 4      3
# 10     1
# Name: count, dtype: int64
# Column cusinter
# cusinter
# 100.0    56
# 200.0    20
# 50.0     20
# 150.0    16
# 60.0     15
# 80.0     13
# 90.0      8
# 130.0     8
# 120.0     8
# 250.0     7
# 10.0      7
# 40.0      7
# 75.0      6
# 30.0      6
# 110.0     6
# 125.0     5
# 70.0      5
# 35.0      5
# 140.0     5
# 95.0      4
# 15.0      4
# 85.0      4
# 65.0      4
# 25.0      4
# 55.0      3
# 20.0      3
# 175.0     3
# 300.0     3
# 5.0       3
# 107.0     2
# 23.0      2
# 45.0      2
# 180.0     2
# 37.0      2
# 350.0     2
# 999.0     1
# 3.0       1
# 240.0     1
# 96.0      1
# 1.0       1
# 63.0      1
# 500.0     1
# 22.0      1
# 135.0     1
# 170.0     1
# 8.0       1
# 97.0      1
# 98.0      1
# 42.0      1
# 4.0       1
# 275.0     1
# 17.0      1
# 33.0      1
# 137.0     1
# Name: count, dtype: int64
# Column yrsfirm
# yrsfirm
# 3.0     134
# 2.0      99
# 1.0      38
# 4.0      12
# 0.0      11
# 6.0       3
# 5.0       3
# 7.0       2
# 10.0      1
# 15.0      1
# Name: count, dtype: int64
# Column educ
# educ
# 2    158
# 1    100
# 3     41
# 4      5
# 5      1
# Name: count, dtype: int64
# Column income
# income
# 2.0    252
# 1.0     29
# 3.0     21
# 4.0      1
# Name: count, dtype: int64
# Column travel_mode
# travel_mode
# 2    101
# 4     85
# 3     76
# 1     25
# 5     18
# Name: count, dtype: int64
